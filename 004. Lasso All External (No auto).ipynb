# %% [markdown]
# # Lasso - External features only

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit

from sklearn.linear_model import Lasso
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df_orig = pd.read_csv('../../full_dataset_unscaled.csv')
df_orig = df_orig.rename(columns={"datetime":"year-month"})
df_orig['net_job_rate']=df_orig['job_creation_rate']-df_orig['job_destruction_rate']
df_orig['apartment_for_rent_searches'] = df_orig[['apartment for rent','studio for rent','1 bedroom for rent','3 bedroom for rent']].sum(axis=1)
df_orig['multifamily_for_rent_searches'] = df_orig[['townhomes for rent','townhouse for rent','house for rent','duplex apartments for rent','condos for rent']].sum(axis=1)
df_orig['gun_searches'] = df_orig[['gun range', 'gun control', 'gun violence']].sum(axis=1)
df_orig['zri'] = np.log(df_orig['zri'])

# %%
gen_cols = ['zip',
 'City',
 'State',
 'Metro',
 'CountyName',
 'zri',
 'year',
 'month',
 'year-month']
acs_cols = ['percent_white',
 'percent_black',
 'percent_asian',
 'percent_hispanic',
 'percent_native_am',
 'percent_other_race',
 'percent_0_17',
 'percent_18_39',
 'percent_40_64',
 'percent_65+',
 'percent_rental_units_vacant',
 'percent_rental_units_occupied',
 'percent_graduate_deg',
 'percent_bachelors',
 'percent_associates',
 'percent_highschool',
 'percent_less_highschool',
 'percent_commute_public_transport',
 'percent_commute_less_30',
 'percent_buildings_less_10_units',
 'percent_buildings_10_19_units',
 'percent_buildings_20_49_units',
 'percent_buildings_50+_units',
 'percent_commute_30_to_59',
 'percent_commute_60_to_89',
 'percent_commute_90_more',
 'percent_new_city',
 'percent_new_unit',
 'percent_units_owner_occupied',
 'median_building_age',
 'income_per_capita',
 'poverty_rate',
 'total_pop',
 'percent_workforce_unemployed',
 'percent_work_from_home',
 'median_age',
 'percent_female',
 'gini_index',
 'percent_not_us_citizen']
acs_cols_remove=['percent_other_race','percent_40_64','percent_0_17','percent_18_39',
       'percent_65+','percent_rental_units_vacant','percent_not_us_citizen','percent_less_highschool', 'percent_buildings_less_10_units',
 'percent_commute_30_to_59',
 'percent_commute_60_to_89',
 'percent_commute_90_more', 'percent_commute_less_30','percent_graduate_deg',
                'percent_female','gini_index','percent_hispanic','percent_black','percent_bachelors',
                 'percent_asian','percent_new_city','percent_new_unit']
acs_cols_keep=list(set(acs_cols) - set(acs_cols_remove))
bikeshare_cols = ['bs_total_stations',
 'bs_total_systems',
 'has_bike_sharing']
bikeshare_cols_remove=['has_bike_sharing','bs_total_systems']
bikeshare_cols_keep=list(set(bikeshare_cols) - set(bikeshare_cols_remove))
trends_cols = ['gun range',
 'gun control',
 'gun violence',
 'job opportunities',
 'unemployment',
 'retirement',
 'layoff',
 'lgbt',
 'same sex marriage',
 'they',
 'pronouns',
 'black lives matter',
 'political correctness',
 'make america great again',
 'euthanasia',
 'getaway',
 'places to go',
 'flight tickets',
 'twitter',
 'hashtag',
 'fake news',
 'hurricane',
 'wildfire',
 'flood',
 'fire',
 "trader joe's",
 'whole foods',
 'lululemon',
 'thrift',
 'condos for rent',
 'duplex apartments for rent',
 'townhomes for rent',
 'townhouses for rent',
 'home for rent',
 'house for rent',
 'townhome for rent',
 'townhouse for rent',
 'apartment for rent',
 'studio for rent',
 '1 bedroom for rent',
 '3 bedroom for rent',
 'starbucks',
  'apartment_for_rent_searches',
  'multifamily_for_rent_searches',
  'gun_searches']
trends_cols_remove=['they','apartment for rent','studio for rent','1 bedroom for rent',
                    '3 bedroom for rent', 'townhome for rent','townhouse for rent','townhomes for rent',
                    'townhouses for rent','house for rent','home for rent','duplex apartments for rent','condos for rent',
                   'gun range', 'gun control', 'gun violence','homes for rent']
trends_cols_keep=list(set(trends_cols) - set(trends_cols_remove))
economic_cols = ['total_firms',
 'job_creation_rate',
 'job_destruction_rate',
 'startup_firms','state_local_perc', 'net_job_rate']
economic_cols_remove=['total_firms', 'job_creation_rate','job_destruction_rate',]
economic_cols_keep=list(set(economic_cols) - set(economic_cols_remove))

# %%
for zipcode in df_orig['zip'].unique():
    globals()[f"scaler_{zipcode}"]=StandardScaler(copy=False)
    df_filtered=df_orig[df_orig['zip']==zipcode]
    df_filtered_train = df_filtered[df_filtered['year']<2019]
    globals()[f"scaler_{zipcode}"].fit(df_filtered_train[['zri']])
    df_orig.loc[df_orig['zip']==zipcode,'zri']=globals()[f"scaler_{zipcode}"].transform(df_filtered[['zri']])

# %%
df_orig = df_orig[gen_cols + acs_cols_keep + bikeshare_cols_keep + economic_cols_keep + trends_cols_keep]

# %%
scale_columns = ['percent_buildings_50+_units', 'percent_associates',
       'percent_rental_units_occupied', 'percent_white', 'percent_highschool',
       'percent_work_from_home', 'percent_buildings_20_49_units',
       'median_building_age', 'median_age', 'percent_commute_public_transport',
       'percent_buildings_10_19_units', 'income_per_capita',
       'percent_native_am', 'percent_workforce_unemployed', 'poverty_rate',
       'percent_units_owner_occupied', 'total_pop', 'bs_total_stations',
       'startup_firms', 'state_local_perc', 'net_job_rate', 'gun_searches',
       'wildfire', 'fire', 'lgbt', 'political correctness', 'lululemon',
       'make america great again', 'same sex marriage', 'job opportunities',
       'retirement', 'black lives matter', 'flight tickets', 'pronouns',
       'trader joe\'s', 'fake news', 'hurricane', 'flood', 'whole foods',
       'twitter', 'thrift', 'hashtag', 'apartment_for_rent_searches', 'layoff',
       'starbucks', 'getaway', 'places to go', 'unemployment', 'euthanasia',
       'multifamily_for_rent_searches']

# %%
for zipcode in df_orig['zip'].unique():
    globals()[f"scaler_features_{zipcode}"]=StandardScaler(copy=False)
    df_filtered=df_orig[df_orig['zip']==zipcode]
    df_filtered_train = df_filtered[df_filtered['year']<2019]
    globals()[f"scaler_features_{zipcode}"].fit(df_filtered_train[scale_columns])
    df_orig.loc[df_orig['zip']==zipcode,scale_columns]=globals()[f"scaler_features_{zipcode}"].transform(df_filtered[scale_columns])

# %%
df_scaled_no_lags = df_orig.copy()

# %%
df_all = df_scaled_no_lags

# %%
def laggenerator(i,colname,df):
    timelist=list(df['year-month'].drop_duplicates().sort_values())[0:i]
    df.loc[:,f'{colname}_lag{i}']=df.loc[:,f'{colname}'].shift(i)
    df.loc[df['year-month'].isin(timelist),f'{colname}_lag{i}']=0
    return df

def laggenerator_diff(i,colname,df):
    timelist=list(df['year-month'].drop_duplicates().sort_values())[0:i+1]
    df.loc[:,f'{colname}_diff_lag{i}_lag{i+1}']=df.loc[:,f'{colname}'].shift(i)-df.loc[:,f'{colname}'].shift(i+1)
    df.loc[df['year-month'].isin(timelist),f'{colname}_diff_lag{i}_lag{i+1}']=0
    return df

def laggenerator_diff12(i,colname,df):
    timelist=list(df['year-month'].drop_duplicates().sort_values())[0:i+11]
    df.loc[:,f'{colname}_diff_lag{i}_lag{i+11}']=df.loc[:,f'{colname}'].shift(i)-df.loc[:,f'{colname}'].shift(i+11)
    df.loc[df['year-month'].isin(timelist),f'{colname}_diff_lag{i}_lag{i+11}']=0
    return df

#ZRI 
def lag_gen(df):
    for i in range(1,12):
        df=laggenerator(i, 'zri', df)
    df=laggenerator_diff12(1, 'zri', df)
    return df

# %%
#ZRI
#df_zri_all = lag_gen(df_zri_all)

#ACS
for col in acs_cols_keep:
    df_all = laggenerator_diff12(1,col,df_all)
    df_all = laggenerator(1,col,df_all)
    df_all = laggenerator(6,col,df_all)
    df_all = laggenerator(12,col,df_all)
    
    
#BIKESHARE AND ECONOMIC 
for col in bikeshare_cols_keep + economic_cols_keep:
    df_all = laggenerator(1, col, df_all)
    df_all = laggenerator_diff12(1, col, df_all)  
    
#TRENDS 
for col in trends_cols_keep:
    for i in range(1,3):
        df_all=laggenerator(i, col, df_all)
    #df_all = laggenerator_diff12(1,col,df_all)

# %%
df = df_all[df_all['year-month']>='2015-04-01']
train = df[(df['year'] < 2019) & (df['year']>=2015)]
test = df[df['year']==2019]

train = train.sort_values(by='year-month',ascending=True)
test = test.sort_values(by='year-month',ascending=True)

save_train = train.copy()
save_test = test.copy()

train = train.drop(['zip','City','State','Metro','CountyName','year','month','year-month'],axis=1)
train_y = train['zri']
train_X = train.drop(['zri'],axis=1)

test = test.drop(['zip','City','State','Metro','CountyName','year','month','year-month'],axis=1)
test_y = test['zri']
test_X = test.drop(['zri'],axis=1)

# %%
#Lasso Grid Search
fold=TimeSeriesSplit(n_splits=5)
lasso = Lasso()
grid = dict()
grid['alpha'] = [0.001,0.01,0.05,0.1,0.5,1,10]
lasso_grid = GridSearchCV(lasso, grid, cv=fold, n_jobs=-1).fit(train_X,train_y)
lasso_best = lasso_grid.best_estimator_

# %%
lasso_best
# Out:
# Lasso(alpha=0.01)

# %%
lasso_best.fit(train_X, train_y)
# Out:
# Lasso(alpha=0.01)

# %%
scaled_predictions_y = pd.Series(lasso_best.predict(test_X))
temp = pd.concat([save_test['zip'],test_y],axis=1)
temp.reset_index(drop=True, inplace=True)
scaled_predictions_y.reset_index(drop=True, inplace=True)
rstable = pd.concat([temp,scaled_predictions_y],axis=1)
rstable.columns = ['zip','zri_test','zri_predicted']



for zipcode in rstable['zip'].unique():
    rstable_filtered=rstable[rstable['zip']==zipcode]
    rstable.loc[rstable['zip']==zipcode,'zri_test']=globals()[f"scaler_{zipcode}"].inverse_transform(rstable_filtered[['zri_test']])
    rstable.loc[rstable['zip']==zipcode,'zri_predicted']=globals()[f"scaler_{zipcode}"].inverse_transform(rstable_filtered[['zri_predicted']])  
rstable.loc[:,'zri_test'] = np.exp(rstable.loc[:,'zri_test']).astype('float128')
rstable.loc[:,'zri_predicted'] = np.exp(rstable.loc[:,'zri_predicted'])
rstable.isna().sum()
# Out:
# zip              0
# zri_test         0
# zri_predicted    0
# dtype: int64

# %%
 rstable.loc[rstable['zri_predicted'] > 1e4,'zip']
# Out:
# Series([], Name: zip, dtype: int64)

# %%
# rstable.replace([np.inf, - np.inf], np.nan, inplace = True)
# rstable = rstable.fillna(0)

# %%
#RESULTS 
r2 = r2_score(rstable['zri_test'],rstable['zri_predicted'])
rmse = sqrt(mean_squared_error(rstable['zri_test'],rstable['zri_predicted']))
print(f'R2: {r2*100}')
print(f'RMSE: {rmse}')
# Out:
# R2: 94.89666314157195
# RMSE: 150.29736556438186

# %%
importance = np.abs(lasso_best.coef_)
coef = lasso_best.coef_
feature_names = train_X.columns
feature_importances= pd.DataFrame([feature_names,importance,coef]).T
feature_importances.columns = ['feature_names','coef_abs','coef']

feature_importances = feature_importances.sort_values(by='coef_abs',ascending=False)
feature_importances['Parent_feature']=feature_importances['feature_names'].apply(lambda x: x[0:x.find('_lag')] if x.find('_lag')!=-1 else x)
feature_importances['Parent_feature']=feature_importances['Parent_feature'].apply(lambda x: x[0:x.find('_diff')] if x.find('_diff')!=-1 else x)

# %%
feature_importances
# Out:
#                                         feature_names  coef_abs      coef  \
# 120                                startup_firms_lag1   0.07284   0.07284
# 183                                 unemployment_lag2  0.071721 -0.071721
# 19                                   state_local_perc  0.063706 -0.063706
# 171                                      twitter_lag2   0.06308  -0.06308
# 182                                 unemployment_lag1  0.059186 -0.059186
# 49                                       unemployment  0.051252 -0.051252
# 43                                            twitter  0.048972 -0.048972
# 121                     startup_firms_diff_lag1_lag12  0.043343 -0.043343
# 170                                      twitter_lag1  0.042021 -0.042021
# 90       percent_workforce_unemployed_diff_lag1_lag12  0.038704 -0.038704
# 123                  state_local_perc_diff_lag1_lag12  0.034271  0.034271
# 20                                       net_job_rate  0.032152  0.032152
# 163                                    fake news_lag2  0.023571  0.023571
# 117                                poverty_rate_lag12  0.022909  0.022909
# 169                multifamily_for_rent_searches_lag2  0.021334  0.021334
# 17                                  bs_total_stations  0.020922 -0.020922
# 1                                       percent_white  0.020645 -0.020645
# 181                                    hurricane_lag2  0.016745  0.016745
# 23                                          starbucks  0.016529  0.016529
# 180                                    hurricane_lag1  0.016439  0.016439
# 37                                 black lives matter   0.01511   0.01511
# 85                          median_building_age_lag12  0.014955  0.014955
# 110                 income_per_capita_diff_lag1_lag12  0.014726  0.014726
# 83                           median_building_age_lag1  0.014399  0.014399
# 131                                    starbucks_lag2  0.014226  0.014226
# 168                multifamily_for_rent_searches_lag1    0.0142    0.0142
# 104                       percent_work_from_home_lag6   0.01388   0.01388
# 48                                          hurricane  0.013832  0.013832
# 147                                        flood_lag2  0.012414  0.012414
# 24                                             thrift  0.012148  0.012148
# 179                                         fire_lag2   0.01207   0.01207
# 167                                         lgbt_lag2  0.011933  0.011933
# 139                                 places to go_lag2  0.011097  0.011097
# 158                           black lives matter_lag1  0.010301  0.010301
# 162                                    fake news_lag1  0.009635  0.009635
# 132                                       thrift_lag1  0.008637  0.008637
# 106     percent_rental_units_occupied_diff_lag1_lag12    0.0069    0.0069
# 153                  apartment_for_rent_searches_lag2    0.0068    0.0068
# 2                        percent_units_owner_occupied  0.006207 -0.006207
# 138                                 places to go_lag1  0.006009  0.006009
# 57                                percent_white_lag12  0.005991 -0.005991
# 16                                       poverty_rate  0.005908  0.005908
# 14                      percent_rental_units_occupied  0.005505  0.005505
# 154                                   euthanasia_lag1  0.005473 -0.005473
# 12                                          total_pop  0.005155  0.005155
# 45                                         retirement  0.004463 -0.004463
# 35                                         euthanasia  0.004272 -0.004272
# 146                                        flood_lag1   0.00381   0.00381
# 31                                              flood   0.00348   0.00348
# 76                            percent_highschool_lag6  0.003234  0.003234
# 125                      net_job_rate_diff_lag1_lag12  0.002677 -0.002677
# 26                                  same sex marriage  0.002676 -0.002676
# 159                           black lives matter_lag2  0.002121  0.002121
# 21                                        whole foods  0.002065 -0.002065
# 18                                      startup_firms  0.002023  0.002023
# 133                                       thrift_lag2  0.001991  0.001991
# 127                                  whole foods_lag2  0.001913 -0.001913
# 152                  apartment_for_rent_searches_lag1  0.001347  0.001347
# 56                                 percent_white_lag6  0.001044 -0.001044
# 130                                    starbucks_lag1  0.000371  0.000371
# 61                 percent_units_owner_occupied_lag12  0.000122 -0.000122
# 129                                 gun_searches_lag2       0.0      -0.0
# 113                           income_per_capita_lag12       0.0      -0.0
# 128                                 gun_searches_lag1       0.0      -0.0
# 112                            income_per_capita_lag6       0.0       0.0
# 118                            bs_total_stations_lag1       0.0      -0.0
# 111                            income_per_capita_lag1       0.0       0.0
# 126                                  whole foods_lag1       0.0      -0.0
# 124                                 net_job_rate_lag1       0.0       0.0
# 119                 bs_total_stations_diff_lag1_lag12       0.0      -0.0
# 114                      poverty_rate_diff_lag1_lag12       0.0      -0.0
# 122                             state_local_perc_lag1       0.0      -0.0
# 115                                 poverty_rate_lag1       0.0       0.0
# 116                                 poverty_rate_lag6       0.0       0.0
# 109               percent_rental_units_occupied_lag12       0.0      -0.0
# 108                percent_rental_units_occupied_lag6       0.0       0.0
# 150                                       layoff_lag1       0.0      -0.0
# 134                            job opportunities_lag1       0.0      -0.0
# 157                                     pronouns_lag2       0.0      -0.0
# 178                                         fire_lag1       0.0       0.0
# 177                                     wildfire_lag2       0.0       0.0
# 176                                     wildfire_lag1       0.0       0.0
# 175                                   retirement_lag2       0.0       0.0
# 174                                   retirement_lag1       0.0      -0.0
# 173                     make america great again_lag2       0.0      -0.0
# 172                     make america great again_lag1       0.0      -0.0
# 166                                         lgbt_lag1       0.0       0.0
# 165                                 trader joe's_lag2       0.0      -0.0
# 164                                 trader joe's_lag1       0.0      -0.0
# 161                               flight tickets_lag2       0.0       0.0
# 160                               flight tickets_lag1       0.0       0.0
# 156                                     pronouns_lag1       0.0      -0.0
# 135                            job opportunities_lag2       0.0      -0.0
# 155                                   euthanasia_lag2       0.0      -0.0
# 151                                       layoff_lag2       0.0      -0.0
# 149                                    lululemon_lag2       0.0      -0.0
# 148                                    lululemon_lag1       0.0      -0.0
# 145                                      getaway_lag2       0.0       0.0
# 144                                      getaway_lag1       0.0       0.0
# 143                                      hashtag_lag2       0.0      -0.0
# 142                                      hashtag_lag1       0.0      -0.0
# 141                        political correctness_lag2       0.0       0.0
# 140                        political correctness_lag1       0.0       0.0
# 137                            same sex marriage_lag2       0.0       0.0
# 136                            same sex marriage_lag1       0.0      -0.0
# 107                percent_rental_units_occupied_lag1       0.0       0.0
# 0                       percent_buildings_10_19_units       0.0       0.0
# 105                      percent_work_from_home_lag12       0.0       0.0
# 44                           make america great again       0.0       0.0
# 34                        apartment_for_rent_searches       0.0       0.0
# 36                                           pronouns       0.0       0.0
# 38                                     flight tickets       0.0      -0.0
# 39                                          fake news       0.0       0.0
# 40                                       trader joe's       0.0       0.0
# 41                                               lgbt       0.0       0.0
# 42                      multifamily_for_rent_searches       0.0       0.0
# 46                                           wildfire       0.0       0.0
# 59                  percent_units_owner_occupied_lag1       0.0      -0.0
# 47                                               fire       0.0       0.0
# 50      percent_buildings_10_19_units_diff_lag1_lag12       0.0       0.0
# 51                 percent_buildings_10_19_units_lag1       0.0       0.0
# 52                 percent_buildings_10_19_units_lag6       0.0       0.0
# 53                percent_buildings_10_19_units_lag12       0.0      -0.0
# 54                      percent_white_diff_lag1_lag12       0.0       0.0
# 55                                 percent_white_lag1       0.0      -0.0
# 33                                             layoff       0.0      -0.0
# 32                                          lululemon       0.0       0.0
# 30                                            getaway       0.0      -0.0
# 29                                            hashtag       0.0      -0.0
# 3                                          median_age       0.0       0.0
# 4                         percent_buildings_50+_units       0.0       0.0
# 5                    percent_commute_public_transport       0.0      -0.0
# 6                                  percent_highschool       0.0       0.0
# 7                                  percent_associates       0.0       0.0
# 8                                 median_building_age       0.0       0.0
# 9                                   percent_native_am       0.0      -0.0
# 10                       percent_workforce_unemployed       0.0      -0.0
# 11                      percent_buildings_20_49_units       0.0      -0.0
# 13                             percent_work_from_home       0.0       0.0
# 15                                  income_per_capita       0.0       0.0
# 22                                       gun_searches       0.0       0.0
# 25                                  job opportunities       0.0      -0.0
# 27                                       places to go       0.0       0.0
# 28                              political correctness       0.0       0.0
# 58       percent_units_owner_occupied_diff_lag1_lag12       0.0       0.0
# 60                  percent_units_owner_occupied_lag6       0.0      -0.0
# 103                       percent_work_from_home_lag1       0.0       0.0
# 94      percent_buildings_20_49_units_diff_lag1_lag12       0.0      -0.0
# 84                           median_building_age_lag6       0.0       0.0
# 86                  percent_native_am_diff_lag1_lag12       0.0      -0.0
# 87                             percent_native_am_lag1       0.0      -0.0
# 88                             percent_native_am_lag6       0.0      -0.0
# 89                            percent_native_am_lag12       0.0      -0.0
# 91                  percent_workforce_unemployed_lag1       0.0      -0.0
# 93                 percent_workforce_unemployed_lag12       0.0       0.0
# 95                 percent_buildings_20_49_units_lag1       0.0      -0.0
# 62                         median_age_diff_lag1_lag12       0.0      -0.0
# 96                 percent_buildings_20_49_units_lag6       0.0      -0.0
# 97                percent_buildings_20_49_units_lag12       0.0      -0.0
# 98                          total_pop_diff_lag1_lag12       0.0       0.0
# 99                                     total_pop_lag1       0.0       0.0
# 100                                    total_pop_lag6       0.0       0.0
# 101                                   total_pop_lag12       0.0       0.0
# 102            percent_work_from_home_diff_lag1_lag12       0.0       0.0
# 82                median_building_age_diff_lag1_lag12       0.0       0.0
# 81                           percent_associates_lag12       0.0       0.0
# 80                            percent_associates_lag6       0.0       0.0
# 79                            percent_associates_lag1       0.0       0.0
# 63                                    median_age_lag1       0.0       0.0
# 64                                    median_age_lag6       0.0       0.0
# 65                                   median_age_lag12       0.0       0.0
# 66        percent_buildings_50+_units_diff_lag1_lag12       0.0       0.0
# 67                   percent_buildings_50+_units_lag1       0.0       0.0
# 68                   percent_buildings_50+_units_lag6       0.0      -0.0
# 69                  percent_buildings_50+_units_lag12       0.0      -0.0
# 70   percent_commute_public_transport_diff_lag1_lag12       0.0      -0.0
# 71              percent_commute_public_transport_lag1       0.0      -0.0
# 72              percent_commute_public_transport_lag6       0.0       0.0
# 73             percent_commute_public_transport_lag12       0.0       0.0
# 74                 percent_highschool_diff_lag1_lag12       0.0       0.0
# 75                            percent_highschool_lag1       0.0       0.0
# 77                           percent_highschool_lag12       0.0       0.0
# 78                 percent_associates_diff_lag1_lag12       0.0      -0.0
# 92                  percent_workforce_unemployed_lag6       0.0       0.0
#
#                        Parent_feature
# 120                     startup_firms
# 183                      unemployment
# 19                   state_local_perc
# 171                           twitter
# 182                      unemployment
# 49                       unemployment
# 43                            twitter
# 121                     startup_firms
# 170                           twitter
# 90       percent_workforce_unemployed
# 123                  state_local_perc
# 20                       net_job_rate
# 163                         fake news
# 117                      poverty_rate
# 169     multifamily_for_rent_searches
# 17                  bs_total_stations
# 1                       percent_white
# 181                         hurricane
# 23                          starbucks
# 180                         hurricane
# 37                 black lives matter
# 85                median_building_age
# 110                 income_per_capita
# 83                median_building_age
# 131                         starbucks
# 168     multifamily_for_rent_searches
# 104            percent_work_from_home
# 48                          hurricane
# 147                             flood
# 24                             thrift
# 179                              fire
# 167                              lgbt
# 139                      places to go
# 158                black lives matter
# 162                         fake news
# 132                            thrift
# 106     percent_rental_units_occupied
# 153       apartment_for_rent_searches
# 2        percent_units_owner_occupied
# 138                      places to go
# 57                      percent_white
# 16                       poverty_rate
# 14      percent_rental_units_occupied
# 154                        euthanasia
# 12                          total_pop
# 45                         retirement
# 35                         euthanasia
# 146                             flood
# 31                              flood
# 76                 percent_highschool
# 125                      net_job_rate
# 26                  same sex marriage
# 159                black lives matter
# 21                        whole foods
# 18                      startup_firms
# 133                            thrift
# 127                       whole foods
# 152       apartment_for_rent_searches
# 56                      percent_white
# 130                         starbucks
# 61       percent_units_owner_occupied
# 129                      gun_searches
# 113                 income_per_capita
# 128                      gun_searches
# 112                 income_per_capita
# 118                 bs_total_stations
# 111                 income_per_capita
# 126                       whole foods
# 124                      net_job_rate
# 119                 bs_total_stations
# 114                      poverty_rate
# 122                  state_local_perc
# 115                      poverty_rate
# 116                      poverty_rate
# 109     percent_rental_units_occupied
# 108     percent_rental_units_occupied
# 150                            layoff
# 134                 job opportunities
# 157                          pronouns
# 178                              fire
# 177                          wildfire
# 176                          wildfire
# 175                        retirement
# 174                        retirement
# 173          make america great again
# 172          make america great again
# 166                              lgbt
# 165                      trader joe's
# 164                      trader joe's
# 161                    flight tickets
# 160                    flight tickets
# 156                          pronouns
# 135                 job opportunities
# 155                        euthanasia
# 151                            layoff
# 149                         lululemon
# 148                         lululemon
# 145                           getaway
# 144                           getaway
# 143                           hashtag
# 142                           hashtag
# 141             political correctness
# 140             political correctness
# 137                 same sex marriage
# 136                 same sex marriage
# 107     percent_rental_units_occupied
# 0       percent_buildings_10_19_units
# 105            percent_work_from_home
# 44           make america great again
# 34        apartment_for_rent_searches
# 36                           pronouns
# 38                     flight tickets
# 39                          fake news
# 40                       trader joe's
# 41                               lgbt
# 42      multifamily_for_rent_searches
# 46                           wildfire
# 59       percent_units_owner_occupied
# 47                               fire
# 50      percent_buildings_10_19_units
# 51      percent_buildings_10_19_units
# 52      percent_buildings_10_19_units
# 53      percent_buildings_10_19_units
# 54                      percent_white
# 55                      percent_white
# 33                             layoff
# 32                          lululemon
# 30                            getaway
# 29                            hashtag
# 3                          median_age
# 4         percent_buildings_50+_units
# 5    percent_commute_public_transport
# 6                  percent_highschool
# 7                  percent_associates
# 8                 median_building_age
# 9                   percent_native_am
# 10       percent_workforce_unemployed
# 11      percent_buildings_20_49_units
# 13             percent_work_from_home
# 15                  income_per_capita
# 22                       gun_searches
# 25                  job opportunities
# 27                       places to go
# 28              political correctness
# 58       percent_units_owner_occupied
# 60       percent_units_owner_occupied
# 103            percent_work_from_home
# 94      percent_buildings_20_49_units
# 84                median_building_age
# 86                  percent_native_am
# 87                  percent_native_am
# 88                  percent_native_am
# 89                  percent_native_am
# 91       percent_workforce_unemployed
# 93       percent_workforce_unemployed
# 95      percent_buildings_20_49_units
# 62                         median_age
# 96      percent_buildings_20_49_units
# 97      percent_buildings_20_49_units
# 98                          total_pop
# 99                          total_pop
# 100                         total_pop
# 101                         total_pop
# 102            percent_work_from_home
# 82                median_building_age
# 81                 percent_associates
# 80                 percent_associates
# 79                 percent_associates
# 63                         median_age
# 64                         median_age
# 65                         median_age
# 66        percent_buildings_50+_units
# 67        percent_buildings_50+_units
# 68        percent_buildings_50+_units
# 69        percent_buildings_50+_units
# 70   percent_commute_public_transport
# 71   percent_commute_public_transport
# 72   percent_commute_public_transport
# 73   percent_commute_public_transport
# 74                 percent_highschool
# 75                 percent_highschool
# 77                 percent_highschool
# 78                 percent_associates
# 92       percent_workforce_unemployed

# %%
feats_agg = feature_importances[['coef_abs','Parent_feature']]
feats_agg['coef_abs'] = feats_agg['coef_abs'].astype('float')
feats_agg_abs = feats_agg.groupby('Parent_feature').agg('mean').sort_values('coef_abs',ascending=False)
feats_agg_abs
# Out:
# <ipython-input-26-0836822478da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feats_agg['coef_abs'] = feats_agg['coef_abs'].astype('float')
#                                   coef_abs
# Parent_feature
# unemployment                      0.060719
# twitter                           0.051358
# startup_firms                     0.039402
# state_local_perc                  0.032659
# hurricane                         0.015672
# multifamily_for_rent_searches     0.011845
# net_job_rate                      0.011610
# fake news                         0.011068
# starbucks                         0.010375
# black lives matter                0.009178
# percent_workforce_unemployed      0.007741
# thrift                            0.007592
# bs_total_stations                 0.006974
# flood                             0.006568
# median_building_age               0.005871
# poverty_rate                      0.005763
# places to go                      0.005702
# percent_white                     0.005536
# fire                              0.004023
# lgbt                              0.003978
# euthanasia                        0.003249
# income_per_capita                 0.002945
# percent_work_from_home            0.002776
# apartment_for_rent_searches       0.002716
# percent_rental_units_occupied     0.002481
# retirement                        0.001488
# whole foods                       0.001326
# percent_units_owner_occupied      0.001266
# total_pop                         0.001031
# same sex marriage                 0.000892
# percent_highschool                0.000647
# political correctness             0.000000
# pronouns                          0.000000
# trader joe's                      0.000000
# percent_buildings_50+_units       0.000000
# percent_native_am                 0.000000
# percent_commute_public_transport  0.000000
# percent_buildings_20_49_units     0.000000
# percent_buildings_10_19_units     0.000000
# percent_associates                0.000000
# median_age                        0.000000
# make america great again          0.000000
# lululemon                         0.000000
# layoff                            0.000000
# job opportunities                 0.000000
# hashtag                           0.000000
# gun_searches                      0.000000
# getaway                           0.000000
# flight tickets                    0.000000
# wildfire                          0.000000

# %%
feats_agg = feature_importances[['coef','Parent_feature']]
feats_agg['coef'] = feats_agg['coef'].astype('float')
feats_agg_sign = feats_agg.groupby('Parent_feature').agg('mean').sort_values('coef',ascending=False)
#feats_agg_sign
# Out:
# <ipython-input-48-4bc9ffa5b676>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feats_agg['coef'] = feats_agg['coef'].astype('float')

# %%
title = 'FINAL_4_No_Auto_All'
fi = title+'_FI'
fi2 = title+'_FI_Agg_sign'
# rstable.to_csv(f'../../../zillow_orientation/Residuals/{title}.csv')
# feature_importances.to_csv(f'../../../zillow_orientation/Residuals/{fi}.csv')
# feats_agg_abs.to_csv(f'../../../zillow_orientation/Residuals/{fi2}.csv')

# %%
rstable['residual']=rstable['zri_predicted']-rstable['zri_test']
rstable['residual_squared']=rstable['residual'].map(lambda x: x**2)
rmse_table=rstable.groupby('zip')[['residual_squared']].agg(['sum','count'])
rmse_table['residual_avgd']=rmse_table['residual_squared']['sum']/rmse_table['residual_squared']['count']
rmse_table['residual_avgd']=rmse_table['residual_avgd'].apply(lambda x: x**0.5)
rmse_table['residual_avgd'].mean()
# Out:
# 97.4910608864369

# %%
 
r2 = r2_score(rstable['zri_test'],rstable['zri_predicted'])
rmse = sqrt(mean_squared_error(rstable['zri_test'],rstable['zri_predicted']))
print(f'R2: {r2*100}')
print(f'RMSE: {rmse}')
# Out:
# R2: 94.89666394064837
# RMSE: 150.29735379766055

# %%
# rstable.to_csv(f'../../../zillow_orientation/Residuals/{title}_rstable.csv')
# rmse_table.to_csv(f'../../../zillow_orientation/Residuals/{title}_rmse.csv')
